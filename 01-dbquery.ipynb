# %%
from pymongo import MongoClient
import pandas as pd
from collections import Counter
import seaborn as sns
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
client = MongoClient("localhost:27017")
client.list_database_names()
# Out:
# ['admin', 'config', 'ironhack', 'local']

# %%
db = client.get_database("ironhack")
db.list_collection_names()
# Out:
# ['companies']

# %%
comps = db.get_collection("companies")
comps
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %%
comps.count_documents({})
# Out:
# 18801

# %% [markdown]
# Query the Database

# %%
comps_query = comps.find(
    {"$and":[
        {"number_of_employees": {"$gte":20}}, 
        {"number_of_employees": {"$lt": 500}},
        {"category_code": "games_video"},
        {"deadpooled_year": None},
        {
            "$or": [ 
                {"total_money_raised": {"$regex": "[A-Za-z]"}},
                {"total_money_raised" : {"$gte": 1000000}},
                    ]
        },              
            ]
    }, {"_id":0, "name":1, "number_of_employees":1, "deadpooled_year":1,  "category_code": 1, "tag_list":1, "total_money_raised": 1, "offices": 1})

comps_query.count()
# Out:
# <ipython-input-41-09d57ac268e3>:16: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   comps_query.count()
# 75

# %%
comps_list = list(comps_query)

# %%
df = pd.DataFrame(comps_list)
df.sample(20)
# Out:
#                      name category_code  number_of_employees deadpooled_year  \
# 34                   MUBI   games_video                   20            None
# 60     Unity Technologies   games_video                  200            None
# 16             Musicshake   games_video                   28            None
# 63                 SCVNGR   games_video                   60            None
# 1          Pando Networks   games_video                   23            None
# 10                Aniboom   games_video                   25            None
# 29                Mytopia   games_video                   29            None
# 7                   Curse   games_video                   58            None
# 53           RGB Networks   games_video                  125            None
# 15                   hulu   games_video                  153            None
# 45                   9You   games_video                  460            None
# 69              PlayScape   games_video                   30            None
# 4                 RockYou   games_video                  106            None
# 22                  Zynga   games_video                  115            None
# 12              MocoSpace   games_video                   25            None
# 21                 Kewego   games_video                   65            None
# 23              GameDuell   games_video                  200            None
# 61  Avocado Entertainment   games_video                   50            None
# 67       Preview Networks   games_video                   26            None
# 35            Modern Feed   games_video                  123            None
#
#                                              tag_list total_money_raised  \
# 34  film, movie, cinema, video, art-house, social-...             $8.25M
# 60  3d, interactive-3d, game-development, content-...             $17.5M
# 16  musicshake, musiccreation, user-generated-musi...              $3.5M
# 63  mobile, game, princeton, dreamit, google-ventu...             $40.8M
# 1                p2p, video, streaming, download, cdn               $11M
# 10  animation-production, cartoon-production, cart...             $14.5M
# 29        techcrunch50, tc50, gaming, social-networks              $3.5M
# 7                                          mmo, curse               $12M
# 53  multiscreen-ip-video, video-processing, transc...               $52M
# 15  hulu, video, embeddable, professional, content...              $100M
# 45                       virtual-world, gaming, games              $100M
# 69                                                                $15.4M
# 4   widgets, photos, avatars, countdown, horoscope...              $136M
# 22  facebookapplications, games, socialnetworking,...              $860M
# 12                           mobile-social-networking             $10.5M
# 21                                                                $19.4M
# 23  games, social, cross-platform, berlin, fun, go...             $17.5M
# 61  social-game, mobile-game, social-and-mobile-ga...              $1.5M
# 67  preview-networks, online, video, syndication, ...                $4M
# 35          video-programming, tv-guide, online-guide                $3M
#
#                                               offices
# 34  [{'description': '', 'address1': '668 High Str...
# 60  [{'description': 'US Office', 'address1': '795...
# 16  [{'description': '', 'address1': '3460 Wilshir...
# 63  [{'description': 'SCVNGR', 'address1': 'One Co...
# 1   [{'description': None, 'address1': '520 Broadw...
# 10  [{'description': None, 'address1': None, 'addr...
# 29  [{'description': '', 'address1': '', 'address2...
# 7   [{'description': 'San Francisco', 'address1': ...
# 53  [{'description': 'HQ', 'address1': '390 West J...
# 15  [{'description': None, 'address1': '12312 W. O...
# 45  [{'description': '', 'address1': '6F Harbour R...
# 69                                                 []
# 4   [{'description': '', 'address1': '585 Broadway...
# 22  [{'description': 'SF HQ', 'address1': '365 Ver...
# 12  [{'description': '', 'address1': '', 'address2...
# 21  [{'description': 'HQ', 'address1': '111, rue C...
# 23  [{'description': 'US Headquarters', 'address1'...
# 61  [{'description': '', 'address1': '', 'address2...
# 67  [{'description': 'European Headquarters', 'add...
# 35  [{'description': None, 'address1': '818 N. La ...

# %%
city_list = list()
for i, offices in enumerate(df["offices"]):
    for office in offices:
        city_list.append(office["city"])
cities_df = pd.DataFrame(city_list, columns=['City'])
cities_df["City"].value_counts()
# Out:
# San Francisco    14
# New York         11
# Los Angeles       6
# Paris             5
# Seattle           4
#                  ..
# Dundee            1
# Brooklyn          1
# Vancouver         1
# Dublin            1
# Boca Raton        1
# Name: City, Length: 62, dtype: int64

# %%
data_list = list()
for index, row in df.iterrows():
    for office in row["offices"]:
        data_list.append([row["name"], row["number_of_employees"], office["city"],office["latitude"], office["longitude"]])
        
companies_df = pd.DataFrame(data_list, columns= ["name", "number_of_employees", "city", "latitude", "longitude"])

# %%
companies_df
# Out:
#                name  number_of_employees           city   latitude   longitude
# 0              Kyte                   40  San Francisco  37.788482 -122.409173
# 1    Pando Networks                   23       New York  40.722655  -73.998730
# 2        Livestream                  120       New York  40.726155  -73.995625
# 3           Ustream                  250  San Francisco  37.392936 -122.079480
# 4           Ustream                  250    Los Angeles        NaN         NaN
# ..              ...                  ...            ...        ...         ...
# 108            Blip                   47   Santa Monica  34.027225 -118.468233
# 109           Exent                  100       New York  40.752380  -74.005568
# 110           Exent                  100   Petach-Tikva        NaN         NaN
# 111           Exent                  100  San Francisco  37.787646 -122.402759
# 112      Tiny Speck                   45      Vancouver  49.282455 -123.109217
#
# [113 rows x 5 columns]

# %%
companies_df["city"].value_counts()
# Out:
# San Francisco    14
# New York         11
# Los Angeles       6
# Paris             5
# Seattle           4
#                  ..
# Dundee            1
# Brooklyn          1
# Vancouver         1
# Dublin            1
# Boca Raton        1
# Name: city, Length: 62, dtype: int64

# %%
sanfran = companies_df.where(companies_df["city"]=="San Francisco").dropna(subset=['latitude', 'longitude'])
sanfran
# Out:
#                    name  number_of_employees           city   latitude  \
# 0                  Kyte                 40.0  San Francisco  37.788482
# 3               Ustream                250.0  San Francisco  37.392936
# 8                   hi5                100.0  San Francisco  37.788668
# 9                 Curse                 58.0  San Francisco  37.787092
# 14           Kongregate                 20.0  San Francisco  37.786942
# 18          Crunchyroll                 50.0  San Francisco  37.781265
# 23              Rupture                 25.0  San Francisco  37.783898
# 27                Zynga                115.0  San Francisco  37.765158
# 50     Serious Business                 22.0  San Francisco  37.789321
# 53       Citizen Sports                 27.0  San Francisco  37.777513
# 65               ngmoco                150.0  San Francisco  37.770510
# 84   Unity Technologies                200.0  San Francisco  55.692461
# 111               Exent                100.0  San Francisco  37.787646
#
#       longitude
# 0   -122.409173
# 3   -122.079480
# 8   -122.400558
# 9   -122.399972
# 14  -122.401245
# 18  -122.393229
# 23  -122.395234
# 27  -122.404234
# 50  -122.401362
# 53  -122.397044
# 65  -122.401581
# 84    12.530107
# 111 -122.402759

# %%
sanfran.to_csv("data/sanfran.csv")

# %%
newyork = companies_df.where(companies_df["city"]=="New York").dropna(subset=['latitude', 'longitude'])
newyork
# Out:
#                     name  number_of_employees      city   latitude  longitude
# 1         Pando Networks                 23.0  New York  40.722655 -73.998730
# 2             Livestream                120.0  New York  40.726155 -73.995625
# 16                OMGPOP                 50.0  New York  40.723384 -74.001704
# 37                Boonty                150.0  New York  40.717248 -74.002662
# 43              Cellufun                 30.0  New York  40.739930 -73.993049
# 82   Major League Gaming                 45.0  New York  40.752672 -73.975930
# 105                Saavn                 25.0  New York  40.743877 -73.986180
# 109                Exent                100.0  New York  40.752380 -74.005568

# %%
paris = companies_df.where(companies_df["city"]=="Paris").dropna(subset=['latitude', 'longitude'])
paris
# Out:
#           name  number_of_employees   city   latitude  longitude
# 26      Kewego                 65.0  Paris  46.227638   2.213749
# 87     Owlient                 40.0  Paris  48.830809   2.303220
# 106  2 Minutes                105.0  Paris  48.850206   2.369803

# %%
sanfran_map = folium.Map(location= [37.788482,-122.409173], zoom_start= 13, height="25%", width="25%", tiles="cartodbpositron")
for index, row in sanfran.iterrows():
    Marker(location = [row["latitude"], row["longitude"]], icon=folium.Icon(color='lightred', icon='building', prefix='fa'), tooltip=row["name"]).add_to(sanfran_map)

newyork_map = folium.Map(location= [40.722655,-73.998730], zoom_start= 10, height="25%", width="25%", tiles="cartodbpositron")
for index, row in newyork.iterrows():
    Marker(location = [row["latitude"], row["longitude"]], icon=folium.Icon(color='lightblue', icon='building', prefix='fa'), tooltip=row["name"]).add_to(newyork_map)
    
paris_map = folium.Map(location= [48.830809,2.303220], zoom_start= 12, height="25%", width="25%", tiles="cartodbpositron")
for index, row in paris.iterrows():
    Marker(location = [row["latitude"], row["longitude"]], icon=folium.Icon(color='lightgreen', icon='building', prefix='fa'), tooltip=row["name"]).add_to(paris_map)

# %%
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e5485d95efe54c5183322c6459e1801e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2025.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%2025.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e5485d95efe54c5183322c6459e1801e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e5485d95efe54c5183322c6459e1801e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e5485d95efe54c5183322c6459e1801e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.788482%2C%20-122.409173%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
newyork_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_901312a779cb43c085c05e09f8cdcd02%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2025.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%2025.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_901312a779cb43c085c05e09f8cdcd02%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_901312a779cb43c085c05e09f8cdcd02%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_901312a779cb43c085c05e09f8cdcd02%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.722655%2C%20-73.99873%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
paris_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2df176096d554adba4856b40e99e70bd%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2025.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%2025.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2df176096d554adba4856b40e99e70bd%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2df176096d554adba4856b40e99e70bd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2df176096d554adba4856b40e99e70bd%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.830809%2C%202.30322%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
